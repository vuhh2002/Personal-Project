# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f1(x):
    return x**2

def f2(x):
    return 10 * np.abs(x-1)

def f3(x):
    return f1(x) - f2(x)

def f4(x):
    return f1(x) + f2(x)

def f5(x):
    return (f1(x) + 2) / (f2(x) + 1)

# %%
y_f5
# Out:
# array([1.40993789, 1.40964157, 1.40934526, ..., 1.6093375 , 1.60963329,
#        1.60992908])

# %%
x = np.linspace(-15, 15, 10000)
y_f1 = f1(x)
plt.plot(x, y_f1, label='f1')
y_f2 = f2(x)
plt.plot(x, y_f2, label='f2')
y_f3 = f3(x)
plt.plot(x, y_f3, label='f3')
# y_f4 = f4(x)
# plt.plot(x, y_f4, label='f4')
y_f5 = f5(x)
plt.plot(x, y_f5, label='f5')
plt.legend()
plt.show()
